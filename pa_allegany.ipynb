# %%
pip install geocoder
# Out:
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 3.5 MB/s eta 0:00:01
# Requirement already satisfied: click in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from geocoder) (8.0.4)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: requests in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from geocoder) (2.27.1)
# Requirement already satisfied: future in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: six in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from geocoder) (1.16.0)
# Requirement already satisfied: decorator in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from ratelim->geocoder) (5.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from requests->geocoder) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from requests->geocoder) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from requests->geocoder) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from requests->geocoder) (1.26.9)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install shapely
# Out:
# Collecting shapely
#   Downloading shapely-2.0.1-cp39-cp39-macosx_10_9_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 7.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.14 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from shapely) (1.21.6)
# Installing collected packages: shapely
# Successfully installed shapely-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyproj
# Out:
# Collecting pyproj
#   Downloading pyproj-3.6.0-cp39-cp39-macosx_10_9_x86_64.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 6.2 MB/s eta 0:00:01
# Requirement already satisfied: certifi in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from pyproj) (2021.10.8)
# Installing collected packages: pyproj
# Successfully installed pyproj-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.13.2-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 7.8 MB/s eta 0:00:01
# Collecting fiona>=1.8.19
#   Downloading Fiona-1.9.4.post1-cp39-cp39-macosx_10_15_x86_64.whl (18.6 MB)
#      |████████████████████████████████| 18.6 MB 137.2 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.1.0 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: packaging in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (21.3)
# Requirement already satisfied: pyproj>=3.0.1 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: six in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (21.4.0)
# Requirement already satisfied: certifi in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (2021.10.8)
# Requirement already satisfied: click~=8.0 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (8.0.4)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: importlib-metadata in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (4.11.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.0->geopandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.0->geopandas) (2021.3)
# Requirement already satisfied: zipp>=0.5 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata->fiona>=1.8.19->geopandas) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/jianingcai/opt/anaconda3/lib/python3.9/site-packages (from packaging->geopandas) (3.0.4)
# Installing collected packages: cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.4.post1 geopandas-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import geocoder
from shapely.geometry import Point, Polygon
from pyproj import CRS
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## read in files

# %%
block = gpd.read_file("/Users/jianingcai/Downloads/tl_2020_42003_tabblock20/tl_2020_42003_tabblock20.shp")

# %%
block
# Out:
#       STATEFP20 COUNTYFP20 TRACTCE20 BLOCKCE20          GEOID20      NAME20  \
# 0            42        003    290400      1020  420032904001020  Block 1020
# 1            42        003    564400      4020  420035644004020  Block 4020
# 2            42        003    191800      6004  420031918006004  Block 6004
# 3            42        003    564400      4015  420035644004015  Block 4015
# 4            42        003    290400      1012  420032904001012  Block 1012
# ...         ...        ...       ...       ...              ...         ...
# 24782        42        003    475101      3005  420034751013005  Block 3005
# 24783        42        003    475101      3013  420034751013013  Block 3013
# 24784        42        003    475102      1012  420034751021012  Block 1012
# 24785        42        003    475101      3001  420034751013001  Block 3001
# 24786        42        003    476200      2002  420034762002002  Block 2002
#
#       MTFCC20  UR20  UACE20  UATYPE20 FUNCSTAT20  ALAND20  AWATER20  \
# 0       G5040   NaN     NaN       NaN          S    14013         0
# 1       G5040   NaN     NaN       NaN          S   330472         0
# 2       G5040   NaN     NaN       NaN          S    30636         0
# 3       G5040   NaN     NaN       NaN          S     7367         0
# 4       G5040   NaN     NaN       NaN          S    13900         0
# ...       ...   ...     ...       ...        ...      ...       ...
# 24782   G5040   NaN     NaN       NaN          S    72608         0
# 24783   G5040   NaN     NaN       NaN          S    44124         0
# 24784   G5040   NaN     NaN       NaN          S   131860         0
# 24785   G5040   NaN     NaN       NaN          S   124610         0
# 24786   G5040   NaN     NaN       NaN          S    20630         0
#
#         INTPTLAT20    INTPTLON20  \
# 0      +40.3846494  -079.9864920
# 1      +40.3819938  -079.7993370
# 2      +40.3877118  -080.0097222
# 3      +40.3866596  -079.7949479
# 4      +40.3861631  -079.9899899
# ...            ...           ...
# 24782  +40.3442018  -080.0440330
# 24783  +40.3419191  -080.0417571
# 24784  +40.3366792  -080.0415310
# 24785  +40.3446465  -080.0362968
# 24786  +40.3641905  -080.0109587
#
#                                                 geometry
# 0      POLYGON ((-79.98860 40.38480, -79.98433 40.384...
# 1      POLYGON ((-79.80365 40.38260, -79.80330 40.382...
# 2      POLYGON ((-80.01082 40.38821, -80.01062 40.388...
# 3      POLYGON ((-79.79530 40.38737, -79.79520 40.387...
# 4      POLYGON ((-79.99101 40.38629, -79.99012 40.386...
# ...                                                  ...
# 24782  POLYGON ((-80.04567 40.34508, -80.04517 40.345...
# 24783  POLYGON ((-80.04365 40.34287, -80.04337 40.343...
# 24784  POLYGON ((-80.04387 40.33798, -80.04385 40.338...
# 24785  POLYGON ((-80.03990 40.34661, -80.03987 40.346...
# 24786  POLYGON ((-80.01206 40.36422, -80.01130 40.364...
#
# [24787 rows x 16 columns]

# %%
# draw out the blocks plot
fig, ax = plt.subplots(1, 1, figsize = (10, 10))
block.plot(ax = ax, edgecolor = "white", linewidth = 0.2)
# Out:
# <AxesSubplot:>

# %%
# read in csv file about the points
pa = pd.read_csv("/Users/jianingcai/Documents/GitHub/national_address_database/data/state_county/pa_allegany.csv.xz", compression = "xz")

# %%
pa
# Out:
#   state    county    zip  longitude   latitude  \
# 0    pa  allegany  14897 -77.824812  41.998112
# 1    pa  allegany  14897 -77.830647  41.998139
#
#                                 address           id
# 0  436 teeter road,whitesville,pa,14897  pa_allegany
# 1  424 teeter road,whitesville,pa,14897  pa_allegany

# %%
# convert pa dataframe into a geo dataframe
geometry=[Point(xy) for xy in zip(pa["longitude"], pa["latitude"])]
crs= CRS('epsg:4326')
pa_map = gpd.GeoDataFrame(pa,crs=crs, geometry=geometry)

# %% [markdown]
# ## do spatial join on the points geodataframe and block geodataframe

# %%
pa_map.crs = block.crs

# %%
join_left_df = gpd.sjoin(block, pa_map, how="right")
join_left_df
# Out:
#    index_left STATEFP20 COUNTYFP20 TRACTCE20 BLOCKCE20 GEOID20 NAME20 MTFCC20  \
# 0         NaN       NaN        NaN       NaN       NaN     NaN    NaN     NaN
# 1         NaN       NaN        NaN       NaN       NaN     NaN    NaN     NaN
#
#    UR20  UACE20  ...  random_point_lat random_point_lng  state    county  \
# 0   NaN     NaN  ...               NaN              NaN     pa  allegany
# 1   NaN     NaN  ...               NaN              NaN     pa  allegany
#
#      zip  longitude   latitude                               address  \
# 0  14897 -77.824812  41.998112  436 teeter road,whitesville,pa,14897
# 1  14897 -77.830647  41.998139  424 teeter road,whitesville,pa,14897
#
#             id                    geometry
# 0  pa_allegany  POINT (-77.82481 41.99811)
# 1  pa_allegany  POINT (-77.83065 41.99814)
#
# [2 rows x 26 columns]

# %% [markdown]
# ## visually test if the points are inside any blocks

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 15))
block.plot(ax = ax)#, edgecolor = "black")
pa_map.plot(ax = ax, color = "red")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## try to use the whole pa state tracks

# %%
blk = gpd.read_file("/Users/jianingcai/Downloads/tl_2020_42_tabblock20/tl_2020_42_tabblock20.shp")

# %%
pa_map.crs = block.crs

# %%
join_left_df2 = gpd.sjoin(blk, pa_map, how="right")
join_left_df2
# Out:
#    index_left STATEFP20 COUNTYFP20 TRACTCE20 BLOCKCE20          GEOID20  \
# 0       30082        42        105    950101      2004  421059501012004
# 1       30082        42        105    950101      2004  421059501012004
#
#        NAME20 MTFCC20  UR20  UACE20  ...   INTPTLAT20    INTPTLON20  state  \
# 0  Block 2004   G5040   NaN     NaN  ...  +41.9954127  -077.8268681     pa
# 1  Block 2004   G5040   NaN     NaN  ...  +41.9954127  -077.8268681     pa
#
#      county    zip  longitude   latitude  \
# 0  allegany  14897 -77.824812  41.998112
# 1  allegany  14897 -77.830647  41.998139
#
#                                 address           id  \
# 0  436 teeter road,whitesville,pa,14897  pa_allegany
# 1  424 teeter road,whitesville,pa,14897  pa_allegany
#
#                      geometry
# 0  POINT (-77.82481 41.99811)
# 1  POINT (-77.83065 41.99814)
#
# [2 rows x 24 columns]

# %%
join_left_df2.county = "potter"
# Out:
#    index_left STATEFP20 COUNTYFP20 TRACTCE20 BLOCKCE20          GEOID20  \
# 0       30082        42        105    950101      2004  421059501012004
# 1       30082        42        105    950101      2004  421059501012004
#
#        NAME20 MTFCC20  UR20  UACE20  ...   INTPTLAT20    INTPTLON20  state  \
# 0  Block 2004   G5040   NaN     NaN  ...  +41.9954127  -077.8268681     pa
# 1  Block 2004   G5040   NaN     NaN  ...  +41.9954127  -077.8268681     pa
#
#    county    zip  longitude   latitude                               address  \
# 0  potter  14897 -77.824812  41.998112  436 teeter road,whitesville,pa,14897
# 1  potter  14897 -77.830647  41.998139  424 teeter road,whitesville,pa,14897
#
#             id                    geometry
# 0  pa_allegany  POINT (-77.82481 41.99811)
# 1  pa_allegany  POINT (-77.83065 41.99814)
#
# [2 rows x 24 columns]

# %% [markdown]
# ## generate points inside the blocks

# %%
def generate_coordinates(polygon):   
    minx, miny, maxx, maxy = polygon.bounds
    while True:
        x = np.random.uniform( minx, maxx )
        y = np.random.uniform( miny, maxy )
        if polygon.contains(Point(x, y)): 
            # reverse
            return x, y

# %%
for i in range(0, len(block)):
    #print(b)
    x, y = generate_coordinates(block.loc[i, 'geometry'])
    block.loc[i, 'random_point_lat'] = x
    block.loc[i, 'random_point_lng'] = y

# %%
block
# Out:
#       STATEFP20 COUNTYFP20 TRACTCE20 BLOCKCE20          GEOID20      NAME20  \
# 0            42        003    290400      1020  420032904001020  Block 1020
# 1            42        003    564400      4020  420035644004020  Block 4020
# 2            42        003    191800      6004  420031918006004  Block 6004
# 3            42        003    564400      4015  420035644004015  Block 4015
# 4            42        003    290400      1012  420032904001012  Block 1012
# ...         ...        ...       ...       ...              ...         ...
# 24782        42        003    475101      3005  420034751013005  Block 3005
# 24783        42        003    475101      3013  420034751013013  Block 3013
# 24784        42        003    475102      1012  420034751021012  Block 1012
# 24785        42        003    475101      3001  420034751013001  Block 3001
# 24786        42        003    476200      2002  420034762002002  Block 2002
#
#       MTFCC20  UR20  UACE20  UATYPE20 FUNCSTAT20  ALAND20  AWATER20  \
# 0       G5040   NaN     NaN       NaN          S    14013         0
# 1       G5040   NaN     NaN       NaN          S   330472         0
# 2       G5040   NaN     NaN       NaN          S    30636         0
# 3       G5040   NaN     NaN       NaN          S     7367         0
# 4       G5040   NaN     NaN       NaN          S    13900         0
# ...       ...   ...     ...       ...        ...      ...       ...
# 24782   G5040   NaN     NaN       NaN          S    72608         0
# 24783   G5040   NaN     NaN       NaN          S    44124         0
# 24784   G5040   NaN     NaN       NaN          S   131860         0
# 24785   G5040   NaN     NaN       NaN          S   124610         0
# 24786   G5040   NaN     NaN       NaN          S    20630         0
#
#         INTPTLAT20    INTPTLON20  \
# 0      +40.3846494  -079.9864920
# 1      +40.3819938  -079.7993370
# 2      +40.3877118  -080.0097222
# 3      +40.3866596  -079.7949479
# 4      +40.3861631  -079.9899899
# ...            ...           ...
# 24782  +40.3442018  -080.0440330
# 24783  +40.3419191  -080.0417571
# 24784  +40.3366792  -080.0415310
# 24785  +40.3446465  -080.0362968
# 24786  +40.3641905  -080.0109587
#
#                                                 geometry  random_point_lat  \
# 0      POLYGON ((-79.98860 40.38480, -79.98433 40.384...        -79.988099
# 1      POLYGON ((-79.80365 40.38260, -79.80330 40.382...        -79.799339
# 2      POLYGON ((-80.01082 40.38821, -80.01062 40.388...        -80.009366
# 3      POLYGON ((-79.79530 40.38737, -79.79520 40.387...        -79.794851
# 4      POLYGON ((-79.99101 40.38629, -79.99012 40.386...        -79.990805
# ...                                                  ...               ...
# 24782  POLYGON ((-80.04567 40.34508, -80.04517 40.345...        -80.043942
# 24783  POLYGON ((-80.04365 40.34287, -80.04337 40.343...        -80.040736
# 24784  POLYGON ((-80.04387 40.33798, -80.04385 40.338...        -80.042051
# 24785  POLYGON ((-80.03990 40.34661, -80.03987 40.346...        -80.033113
# 24786  POLYGON ((-80.01206 40.36422, -80.01130 40.364...        -80.010246
#
#        random_point_lng
# 0             40.384699
# 1             40.381252
# 2             40.388218
# 3             40.386979
# 4             40.385631
# ...                 ...
# 24782         40.344471
# 24783         40.341229
# 24784         40.337284
# 24785         40.344678
# 24786         40.365336
#
# [24787 rows x 18 columns]

# %%
random_points = [Point(xy) for xy in zip(block["random_point_lat"], block["random_point_lng"])]

# %%
crs= CRS('epsg:4326')
random_points_map = gpd.GeoDataFrame(random_points,crs=crs, geometry=random_points)

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 15))
block.plot(ax = ax, edgecolor = "white", linewidth = 0.5)#, edgecolor = "black")
random_points_map.plot(ax = ax, color = "orange", markersize = 0.5)
# Out:
# <AxesSubplot:>

# %%
len(block.GEOID20.unique())
# Out:
# 24787

# %%
for i in range(0, len(block)):
    x = block.loc[i, 'random_point_lat'] 
    y = block.loc[i, 'random_point_lng'] 
    result = geocoder.bing([x, y], method = "reverse", key = "An0lDWpMaQxpHz_yRGUihycKpSmv1UG6_JryfLZgyPbleFH2s4ObalS4QWAn2KQE")

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
geolocator = Nominatim(user_agent = "UVA_BII", timeout = 5)
reverse = RateLimiter(geolocator.reverse, min_delay_seconds = 1, max_retries = 1)

# %%
for i in range(0, 10):
    x = block.loc[i, 'random_point_lat'] 
    y = block.loc[i, 'random_point_lng'] 
    #result = geocoder.bing([x, y], method = "reverse", key = "An0lDWpMaQxpHz_yRGUihycKpSmv1UG6_JryfLZgyPbleFH2s4ObalS4QWAn2KQE")
    block.loc[i, 'random_point_address'] = reverse("{}, {}".format(x, y)).raw['address']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-998a7e94f8de> in <module>
#       3     y = block.loc[i, 'random_point_lng']
#       4     #result = geocoder.bing([x, y], method = "reverse", key = "An0lDWpMaQxpHz_yRGUihycKpSmv1UG6_JryfLZgyPbleFH2s4ObalS4QWAn2KQE")
# ----> 5     block.loc[i, 'random_point_address'] = reverse("{}, {}".format(x, y)).raw['address']
#
# AttributeError: 'NoneType' object has no attribute 'raw'
